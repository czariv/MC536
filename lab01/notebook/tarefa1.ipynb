# %%
import io
import requests
import json
import xml.etree.ElementTree as et

# %% [markdown]
# Primeiramente vou importar uma api do pubchem em formato xml, montei o link da api de forma a obter alguns dados interessantes sobre alguns compostos químicos encontrados em algumas drogas ilicitas.

# %%
url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/cid/702,2543,446220,5462328/property/Title,MolecularFormula,MolecularWeight,CanonicalSMILES,IUPACName/xml"
data = requests.get(url).content
x = et.parse(io.StringIO(data.decode("utf-8")))
print(data.decode("utf-8"))
# Out:
# <?xml version="1.0"?>
# <PropertyTable
#     xmlns="http://pubchem.ncbi.nlm.nih.gov/pug_rest"
#     xmlns:xs="http://www.w3.org/2001/XMLSchema-instance"
#     xs:schemaLocation="http://pubchem.ncbi.nlm.nih.gov/pug_rest https://pubchem.ncbi.nlm.nih.gov/pug_rest/pug_rest.xsd"
# >
#   <Properties>
#     <CID>702</CID>
#     <MolecularFormula>C2H6O</MolecularFormula>
#     <MolecularWeight>46.07</MolecularWeight>
#     <CanonicalSMILES>CCO</CanonicalSMILES>
#     <IUPACName>ethanol</IUPACName>
#     <Title>Ethanol</Title>
#   </Properties>
#   <Properties>
#     <CID>2543</CID>
#     <MolecularFormula>C21H26O2</MolecularFormula>
#     <MolecularWeight>310.4</MolecularWeight>
#     <CanonicalSMILES>CCCCCC1=CC(=C2C(=C1)OC(C3=C2C=C(C=C3)C)(C)C)O</CanonicalSMILES>
#     <IUPACName>6,6,9-trimethyl-3-pentylbenzo[c]chromen-1-ol</IUPACName>
#     <Title>Cannabinol</Title>
#   </Properties>
#   <Properties>
#     <CID>446220</CID>
#     <MolecularFormula>C17H21NO4</MolecularFormula>
#     <MolecularWeight>303.35</MolecularWeight>
#     <CanonicalSMILES>CN1C2CCC1C(C(C2)OC(=O)C3=CC=CC=C3)C(=O)OC</CanonicalSMILES>
#     <IUPACName>methyl (1R,2R,3S,5S)-3-benzoyloxy-8-methyl-8-azabicyclo[3.2.1]octane-2-carboxylate</IUPACName>
#     <Title>Cocaine</Title>
#   </Properties>
#   <Properties>
#     <CID>5462328</CID>
#     <MolecularFormula>C21H23NO5</MolecularFormula>
#     <MolecularWeight>369.4</MolecularWeight>
#     <CanonicalSMILES>CC(=O)OC1C=CC2C3CC4=C5C2(C1OC5=C(C=C4)OC(=O)C)CCN3C</CanonicalSMILES>
#     <IUPACName>[(4R,4aR,7S,7aR,12bS)-9-acetyloxy-3-methyl-2,4,4a,7,7a,13-hexahydro-1H-4,12-methanobenzofuro[3,2-e]isoquinolin-7-yl] acetate</IUPACName>
#     <Title>Heroin</Title>
#   </Properties>
# </PropertyTable>

# %% [markdown]
# Depois analisei o resultado do request, imprimindo todos os dados para fazer uma analise. Decidi então encontrar o nome de cada composto especifica

# %%
root=x.getroot()
print(root.tag)
# Out:
# {http://pubchem.ncbi.nlm.nih.gov/pug_rest}PropertyTable

# %% [markdown]
# Achando o nome da root endendi um pouco mais sobre a nomeclatura nessa api

# %%
for child in root:
    print(child.tag)
    for c in child:
        print("- "+c.tag)
# Out:
# {http://pubchem.ncbi.nlm.nih.gov/pug_rest}Properties
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}CID
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}MolecularFormula
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}MolecularWeight
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}CanonicalSMILES
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}IUPACName
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}Title
# {http://pubchem.ncbi.nlm.nih.gov/pug_rest}Properties
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}CID
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}MolecularFormula
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}MolecularWeight
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}CanonicalSMILES
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}IUPACName
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}Title
# {http://pubchem.ncbi.nlm.nih.gov/pug_rest}Properties
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}CID
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}MolecularFormula
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}MolecularWeight
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}CanonicalSMILES
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}IUPACName
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}Title
# {http://pubchem.ncbi.nlm.nih.gov/pug_rest}Properties
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}CID
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}MolecularFormula
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}MolecularWeight
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}CanonicalSMILES
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}IUPACName
# - {http://pubchem.ncbi.nlm.nih.gov/pug_rest}Title

# %% [markdown]
# Depois eu achei o nome do caminho que eu teria que percorrer

# %%
for child in root:
    print(child.find("{http://pubchem.ncbi.nlm.nih.gov/pug_rest}Title").text)
# Out:
# Ethanol
# Cannabinol
# Cocaine
# Heroin

# %% [markdown]
# Agora vou fazer a analise dos dados obtidos na api da world health organization, estou pegando uma base de dados sobre uso de drogas em formato json.

# %%
url = "https://apps.who.int/gho/athena/api/RSUDSUBSTANCEDEPENDENCE?filter=CONTRY:USA&format=json"
js = requests.get(url).content
print(js.decode("utf-8"))
# Out:
# {
# "copyright": "(c) World Health Organization",
# "dataset":
# [
# ],
# "attribute":
# [
# ],
# "dimension":
# [
# {
# "label": "RSUDSUBSTANCEDEPENDENCE",
# "display": "Substance dependence",
# "isMeasure": false,
# "code":
# [
# {
# "label": "ALCOHOL_DEPENDENCE",
# "display": "Alcohol dependence",
# "display_sequence": 0,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "COCAINE_DEPENDENCE",
# "display": "Cocaine dependence",
# "display_sequence": 0,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "OPIOID_DEPENDENCE",
# "display": "Opioid dependence",
# "display_sequence": 0,
# "url": "",
# "attr":
# [
# ]
# },
# {
# "label": "CANNABIS_DEPENDENCE",
# "display": "Cannabis dependence",
# "display_sequence": 0,
# "url": "",
# "attr":
# [
# ]
# }
# ]
# }
# ],
# "fact":
# [
# ]
# }

# %% [markdown]
# Primeiro analisei o resultado do request, como feito anteriormente e decidi imprimir os tipos de vicios

# %%
data = requests.get(url)
js=data.json()
for i in range(4):
    print(js["dimension"][0]["code"][i]["display"])
# Out:
# Alcohol dependence
# Cocaine dependence
# Opioid dependence
# Cannabis dependence
